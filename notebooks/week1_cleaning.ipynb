# %%
import pandas as pd

df = pd.read_csv('../data/candidates.csv')
# print(df.head())
# print(df.info())
# print(df.describe())
# print(df.isnull().sum())
df['Skills']=df['Skills'].str.lower().str.strip()
df['Domain']=df['Domain'].str.strip()
df=df.dropna(subset=['Skills','Role'])
df.fillna('Unknown', inplace=True)
print(df.shape)
print(df.isnull().sum())
# Out:
# Index(['Name', 'Skills', 'Domain', 'Role', 'Experience'], dtype='object')
# Name          0
# Skills        0
# Domain        0
# Role          0
# Experience    0
# dtype: int64
